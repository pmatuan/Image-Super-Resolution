# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/Shareddrives/PMAT/Datasets/high
# Out:
# /content/drive/Shareddrives/PMAT/Datasets/high

# %%
# !wget http://data.vision.ee.ethz.ch/cvl/DIV2K/DIV2K_train_HR.zip
# !wget http://data.vision.ee.ethz.ch/cvl/DIV2K/DIV2K_valid_HR.zip
# Out:
# --2022-01-22 12:57:01--  http://data.vision.ee.ethz.ch/cvl/DIV2K/DIV2K_train_HR.zip
# Resolving data.vision.ee.ethz.ch (data.vision.ee.ethz.ch)... 129.132.52.178, 2001:67c:10ec:36c2::178
# Connecting to data.vision.ee.ethz.ch (data.vision.ee.ethz.ch)|129.132.52.178|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://data.vision.ee.ethz.ch/cvl/DIV2K/DIV2K_train_HR.zip [following]
# --2022-01-22 12:57:01--  https://data.vision.ee.ethz.ch/cvl/DIV2K/DIV2K_train_HR.zip
# Connecting to data.vision.ee.ethz.ch (data.vision.ee.ethz.ch)|129.132.52.178|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3530603713 (3.3G) [application/zip]
# Saving to: ‘DIV2K_train_HR.zip’
#
# DIV2K_train_HR.zip  100%[===================>]   3.29G  22.9MB/s    in 2m 22s
#
# 2022-01-22 12:59:24 (23.7 MB/s) - ‘DIV2K_train_HR.zip’ saved [3530603713/3530603713]
#
# --2022-01-22 12:59:24--  http://data.vision.ee.ethz.ch/cvl/DIV2K/DIV2K_valid_HR.zip
# Resolving data.vision.ee.ethz.ch (data.vision.ee.ethz.ch)... 129.132.52.178, 2001:67c:10ec:36c2::178
# Connecting to data.vision.ee.ethz.ch (data.vision.ee.ethz.ch)|129.132.52.178|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://data.vision.ee.ethz.ch/cvl/DIV2K/DIV2K_valid_HR.zip [following]
# --2022-01-22 12:59:24--  https://data.vision.ee.ethz.ch/cvl/DIV2K/DIV2K_valid_HR.zip
# Connecting to data.vision.ee.ethz.ch (data.vision.ee.ethz.ch)|129.132.52.178|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 448993893 (428M) [application/zip]
# Saving to: ‘DIV2K_valid_HR.zip’
#
# DIV2K_valid_HR.zip  100%[===================>] 428.19M  23.1MB/s    in 22s
#
# 2022-01-22 12:59:47 (19.6 MB/s) - ‘DIV2K_valid_HR.zip’ saved [448993893/448993893]

# %%
# !mkdir Train
# !unzip -q DIV2K_train_HR.zip -d Train
# !mkdir Valid
# !unzip -q DIV2K_valid_HR.zip -d Valid

# %%
# %cd /content/drive/Shareddrives/PMAT/Datasets/low
# Out:
# /content/drive/Shareddrives/PMAT/Datasets/low

# %%
# !wget http://data.vision.ee.ethz.ch/cvl/DIV2K/DIV2K_train_LR_x8.zip
# !wget http://data.vision.ee.ethz.ch/cvl/DIV2K/DIV2K_valid_LR_x8.zip
# Out:
# --2022-01-22 13:01:35--  http://data.vision.ee.ethz.ch/cvl/DIV2K/DIV2K_train_LR_x8.zip
# Resolving data.vision.ee.ethz.ch (data.vision.ee.ethz.ch)... 129.132.52.178, 2001:67c:10ec:36c2::178
# Connecting to data.vision.ee.ethz.ch (data.vision.ee.ethz.ch)|129.132.52.178|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://data.vision.ee.ethz.ch/cvl/DIV2K/DIV2K_train_LR_x8.zip [following]
# --2022-01-22 13:01:35--  https://data.vision.ee.ethz.ch/cvl/DIV2K/DIV2K_train_LR_x8.zip
# Connecting to data.vision.ee.ethz.ch (data.vision.ee.ethz.ch)|129.132.52.178|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 65753171 (63M) [application/zip]
# Saving to: ‘DIV2K_train_LR_x8.zip’
#
# DIV2K_train_LR_x8.z 100%[===================>]  62.71M  14.7MB/s    in 4.3s
#
# 2022-01-22 13:01:40 (14.7 MB/s) - ‘DIV2K_train_LR_x8.zip’ saved [65753171/65753171]
#
# --2022-01-22 13:01:40--  http://data.vision.ee.ethz.ch/cvl/DIV2K/DIV2K_valid_LR_x8.zip
# Resolving data.vision.ee.ethz.ch (data.vision.ee.ethz.ch)... 129.132.52.178, 2001:67c:10ec:36c2::178
# Connecting to data.vision.ee.ethz.ch (data.vision.ee.ethz.ch)|129.132.52.178|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://data.vision.ee.ethz.ch/cvl/DIV2K/DIV2K_valid_LR_x8.zip [following]
# --2022-01-22 13:01:41--  https://data.vision.ee.ethz.ch/cvl/DIV2K/DIV2K_valid_LR_x8.zip
# Connecting to data.vision.ee.ethz.ch (data.vision.ee.ethz.ch)|129.132.52.178|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8428103 (8.0M) [application/zip]
# Saving to: ‘DIV2K_valid_LR_x8.zip’
#
# DIV2K_valid_LR_x8.z 100%[===================>]   8.04M  6.94MB/s    in 1.2s
#
# 2022-01-22 13:01:42 (6.94 MB/s) - ‘DIV2K_valid_LR_x8.zip’ saved [8428103/8428103]

# %%
# !mkdir Train
# !unzip -q DIV2K_train_LR_x8.zip -d Train
# !mkdir Valid
# !unzip -q DIV2K_valid_LR_x8.zip -d Valid
# Out:
# mkdir: cannot create directory ‘Train’: File exists
# mkdir: cannot create directory ‘Valid’: File exists
