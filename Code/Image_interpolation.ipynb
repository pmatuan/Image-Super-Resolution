# %%
import numpy as np
import cv2
from google.colab.patches import cv2_imshow

# %%
lr = cv2.imread('0829x8.png')
lr = cv2.resize(lr, (256,256), interpolation=cv2.INTER_AREA)
cv2_imshow(lr)
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FAE5F9B1C10>

# %%
HR = cv2.imread('0829.png')
HR = cv2.resize(HR, (256,256), interpolation=cv2.INTER_CUBIC)
cv2_imshow(HR)
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FAE5F9DE250>

# %%
cubic = cv2.imread('0829x8.png')
cubic = cv2.resize(cubic, (256,256), interpolation=cv2.INTER_CUBIC)
cv2_imshow(cubic)
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FAE5F16E410>

# %%
bilinear = cv2.imread('0829x8.png')
bilinear = cv2.resize(bilinear, (256,256), interpolation=cv2.INTER_LINEAR)
cv2_imshow(bilinear)
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FAE5F16EC10>

# %%
nn = cv2.imread('0829x8.png')
nn = cv2.resize(nn, (256,256), interpolation=cv2.INTER_NEAREST)
cv2_imshow(nn)
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FAE5F173510>
